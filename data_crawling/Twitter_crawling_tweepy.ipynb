# %%
# twitter crawling

import tweepy

# 트위터 앱의 Keys and Access Tokens 탭 참조(자신의 설정 값을 넣어준다)
consumer_key = "cb9kA5yYTmFKKllC4p4gQd7iy"
consumer_secret = "LhNRXQrhmR6RiNQnlcUUNV8newRXOUtEAMPmZDDeCsn8MugDqP"

# 1. 인증요청(1차) : 개인 앱 정보 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

access_token = "988971579705995264-cOPOtBkgeTZqpZJJZPtVQaCAIrPHKpg"
access_token_secret= "8dsK1bdD0evnfjmPqclq12kSCHorzIaL2lH8jdLhf3Ws1"

# 2. access 토큰 요청(2차) - 인증요청 참조변수 이용
auth.set_access_token(access_token, access_token_secret)

# 3. twitter API 생성  
api = tweepy.API(auth)

keyword = "슬프다";     # 자신이 검색하고 싶은 키워드 입력 
search = [] # 크롤링 결과 저장할 변수   

cnt = 1
while(cnt <= 10):   # 10page 대상으로 크롤링
   tweets = api.search(keyword)
   for tweet in tweets:
       search.append(tweet)
   cnt += 1

print(len(search)) # 문서 길이 
print(search[0]) # 첫번째 text 보기
# Out:
# 150
# ...

# %%
#전체 문서 보기

data = {}   # 전체 문서 추가
i = 0       # 문서 번호
for tweet in search:
    data['text'] = tweet.text   # text키에 text문서 저장
    print(i, " : ", data)   # 문서번호 : 문서내용
    i += 1
# Out:
# 0  :  {'text': '일할때는 돈 안모이면 불안해서 못살았는데\n이젠 의미 없다는게 너무 슬프다'}
# 1  :  {'text': 'RT @harrystylesdeep: #미친듯이_웃은짤을_올려보자\n진짜 많은데 네 장 밖에 못올려수 슬프다 새벽에 보면서 개쳐웃엇엇늠ㅋㅋㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠ https://t.co/IIezrbhZkc'}
# 2  :  {'text': 'RT @harrystylesdeep: #미친듯이_웃은짤을_올려보자\n진짜 많은데 네 장 밖에 못올려수 슬프다 새벽에 보면서 개쳐웃엇엇늠ㅋㅋㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠ https://t.co/IIezrbhZkc'}
# 3  :  {'text': '@mlskboy_2 흑흑 슬프다'}
# 4  :  {'text': 'RT @BadxxxBitch: 이 만화는 볼때마다 슬프다. 아무 이유 없이 갑자기 떠나는 사람들은 없겠지. 그저 말할 수가 없었을 뿐. https://t.co/mCAz6lj1cK'}
# 5  :  {'text': 'RT @piecesaebyeol: 워낙 많은 사람들이 보는 계정이라 말을 아꼈지만, 어떤 창작물이 세상에 나오면 (내경우는 만화)완결 날때 몰아서 보겠다는 말이 조금 슬프게 다가온다. 사실 아무탈 없이 끝까지 쭉 갈 수 있다면 좋지만 모든 콘텐츠들이…'}
# 6  :  {'text': 'RT @harrystylesdeep: #미친듯이_웃은짤을_올려보자\n진짜 많은데 네 장 밖에 못올려수 슬프다 새벽에 보면서 개쳐웃엇엇늠ㅋㅋㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠ https://t.co/IIezrbhZkc'}
# 7  :  {'text': '@IBGDRGN 좀 슬프다 오늘 ㅠㅠㅠ'}
# 8  :  {'text': '집 가서 봐야지 ㅠㅡㅠ 슬프다....'}
# 9  :  {'text': 'RT @harrystylesdeep: #미친듯이_웃은짤을_올려보자\n진짜 많은데 네 장 밖에 못올려수 슬프다 새벽에 보면서 개쳐웃엇엇늠ㅋㅋㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠ https://t.co/IIezrbhZkc'}
# ...

# %%
# 전체 문서를 파일 저장

import os

wfile = open(os.getcwd()+"/twitter_슬픔.txt", mode='w')   # 쓰기 모드
data = {}   # 전체 문서 추가
i = 0       # 문서 번호

for tweet in search:
    data['text'] = tweet.text   # text키에 text문서 저장
    wfile.write(data['text']+'\n')  # 파일 출력
    i += 1

wfile.close()
