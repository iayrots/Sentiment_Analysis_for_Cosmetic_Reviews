# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time
import re

# %%
columns = ['product', 'point', 'review']
df = pd.DataFrame(columns=columns)

driver = webdriver.Chrome('/Users/yunah/Downloads/chromedriver')
for number in range(1, 31000):
    driver.get('https://www.glowpick.com/product/' + str(number))
    
    # 예외처리
    try:
        table = driver.find_element_by_css_selector('#gp-product-detail > div')
        review = table.find_element_by_css_selector('ul.section-list-wrap.side-bottom > li.section-list-review.side-right > section > ul > li:nth-child(1) > div > p')
        if review is None:
            continue
    except:
        continue
    
    
    
    table = driver.find_element_by_css_selector('#gp-product-detail > div')
    data = {
        'product' : table.find_element_by_css_selector('h1').text,
        'point' : table.find_element_by_css_selector('p.score').text,
        'review' : table.find_element_by_css_selector('ul.section-list-wrap.side-bottom > li.section-list-review.side-right > section > ul > li:nth-child(1) > div > p').text,
    }
    df.loc[len(df)] = data

driver.close()

# %%
df
# Out:
#                            product point  \
# 0                         틴트바 트리플샷  3.30
# 1                        틴트바 밀크콜라다  4.20
# 2                          틴트바 젤티니  3.13
# 3      겔랑 루즈 G 드 세리 느와르 쥬얼 립스틱 컴팩트  3.96
# 4                         루즈 오토마띠끄  4.21
# 5                        크렘 드 루즈 G  4.80
# 6                              립스틱  4.06
# 7                    샤인 블라썸 로즈 립스틱  2.14
# 8                      레브드미엘 스틱레브르  3.85
# 9                     본 리피립밤 스트로베리  3.17
# 10                    페이스잇 스키니핏글로스  2.00
# 11             페이스 잇 올어바웃 립스틱 모이스쳐  2.80
# 12                 러블리 믹스 러브 마크 틴트  1.91
# 13                      러블리믹스 밀키틴트  2.28
# 14           어딕트 립 글로우 컬러 어웨이크닝 립밤  3.72
# 15                     어딕트 울트라 글로스  3.58
# 16                    어딕트 익스트림 립스틱  4.16
# 17               스노우 크리스탈 모이스처 립스틱  3.33
# 18                      실크 인텐스 립스틱  3.15
# 19                글램3 익스트림 소프트 립스틱  3.00
# 20                          압솔뤼 루즈  4.55
# 21                       블루밍 립 글라세  3.22
# 22                 컬리리쉬 뉴트리 샤인 립스틱  3.89
# 23                  샤인 모이스트 볼륨 글로스  4.50
# 24              디자이닝 글램루즈 - 촉촉한 타입  3.81
# 25                        클리어 립글라스  3.20
# 26                    립 컨디셔너 SPF15  3.83
# 27                틴티드 립 컨디셔너 SPF15  4.00
# 28                        쉰수프림 립스틱  4.18
# 29                      프로 롱웨어 립크림  4.17
# ...                            ...   ...
# 19908               ZZ 센스티브 페이셜 토너  3.71
# 19909               콤비네이션스킨 페이셜 토너  3.00
# 19910               뷰티 펄 리제네레이션 세럼  3.90
# 19911               스페셜케어 바이탈 플루이드  5.00
# 19912                      페이셜 퍼밍젤  4.00
# 19913           콤비네이션스킨 라이트 데이 에센스  4.34
# 19914          베이비 썬스크린 SPF20 PA++  2.97
# 19915         베이비 썬스틱 SPF 33 PA+++  5.00
# 19916                           로션  3.14
# 19917                         바텀 밤  4.34
# 19918  썬 프로텍트 내추럴 크림 [SPF35/PA+++]  5.00
# 19919             오뜨 피니쉬 케이크 SPF15  3.75
# 19920                        블랑쉬로션  4.67
# 19921                         CC크림  2.50
# 19922                      단백질 클리닉  4.05
# 19923                  CP-1 단백질 샴푸  4.24
# 19924                           로션  5.00
# 19925                   에이디파잉 스킨토너  4.67
# 19926                    에이디파잉 에멀젼  4.67
# 19927                 화산수 아이스 폼클렌징  3.00
# 19928                       화산수 토너  4.00
# 19929               페이스 프로텍티브 모이스처  3.00
# 19930                  퍼펙팅 뉴트리션 크림  1.50
# 19931                  릴렉세이션 케어 세럼  4.33
# 19932                 페이스 프레스트 파우더  3.69
# 19933                스킨 퓨전 메이크업베이스  3.67
# 19934           퍼펙트 오거나이징 액티비티 리페어  3.80
# 19935              매직수분BB크림 [보습타입]  3.97
# 19936                 작은 모공 아씨들 코팩  3.50
# 19937    미니페이스 화이트 클레이 포어 퓨리파잉 마스크  3.56
#
#                                                   review
# 0      트리플어피치 쓰는데 음... 발색도 별로 텍스쳐가 정말 뭐라하지 너무 기름진데 촉촉...
# 1                                치크로만 쓰는데 굉장히 여리여리라게 발색됨
# 2      색은 둘째치고 틴트가 지속력이 없음. 올려도 지워지니 살 필요가 없다. 립브러쉬 쓰...
# 3      루즈G 립스틱이랑 세트인 컴팩트!\n\n일단 컴팩트 디자인이 엄청 다양해요ㅎ\n심플...
# 4      164 쓰는데 고급진 핑크에요~~ 발림성이 너무 맘에 들었어요 지속은 좀 아쉬웠고 ...
# 5      원래 립스틱타입 쓰다가 매장언니 추천으로 샀는데 이가격에도 쓰게되는 애증의 아이템임...
# 6      어두운 피부에도 살짝하면 자연스럽게 얼굴 밝혀주고 풀로 하면 캬..전 여기에다가 입...
# 7         케이스 이뻐서 샀는데 너무 촉촉함 지속력이 너무 없다ㅠㅜㅜ 그래도 꿋꿋이 발랐었어요
# 8      상큼한 레몬향\n촉촉하고 산뜻하게 보습이 돼요\n겨울에는 좀 부족할 듯\n다른 립밤...
# 9      케이스 귀엽\n\n향은 진짜 좋음\n\n이것만 바르면 목이 따갑고 먼지 먹은 느낌\...
# 10                                            찐득...찐득...
# 11                          저한텐많이 매트하진않았지만\n발색이 거의나질않네요ㅠ
# 12     ㅋㅋㅋㅋㅋㅋㅋ 중1때 막 유튜브에 파우치 소개 영상같은 거 보다가 이 틴트 사람들이...
# 13                           얘는 단종 되었지만 학생틴트로 추천해요 !!!!!
# 14     선물받은거라 무슨 제품인지모르고 막 발라재꼈었는데 매트가아닌컬러도 있었네요;\n1월...
# 15     557호랑 765호를 섞어서 쓰는데 이뻐요 ㅎㅎ\n물론 40000원이라 비싸긴 하지...
# 16                            비싼 가격에 성분 안좋은걸 사서 먹었구나요 ㅜㅜ
# 17     구매한 색상: 17호 파티레드\n지속력은 좋은데 딱히 이 돈내고 사기엔 아닌 것같네...
# 18                                       겉돌고 각질 부각이 되요..
# 19                                 촉촉하고 발림성이 좋은데 발색이 약해요
# 20     제품 디자인이 한 몫한 듯\n너무 예뻐... 진짜 금장미에 랑콤 각인 너무 예뻐.....
# 21     샘플인지 쪼끄만한데 그래도 베이스로 깔아주면 그 위에 어떤 틴트를 올려도 이쁘고 건...
# 22     <개인적으로 핑크 안어울림>\n핑크나 오렌지 레드 보다는 코랄 빛이 매우 강하고 촉...
# 23              피부결이 예쁘게 보이게 해줌 이건 진짜 좋음 한가지 아쉬운건 높은 가격임
# 24     부드럽고 촉촉하고 발색도 좋아요^^ 보통 촉촉한것 같아도 시간이 지나면 좀 마르는 ...
# 25     투명 글로스중에 가장 좋습니다 최근 촉촉한 텍스처가 다시 유행해서 사봤는데 립스틱으...
# 26     이 제품이 메이크업브랜드임에도 진짜 좋은 성분이라고 해서 구매해봤는데, 저는 립스틱...
# 27        괜찮아요\n요즘 등에 등드름이\n나서 사용중인데\n지켜봐야 알겠지만 가라앉고 있어요
# 28                             색도 예쁘고 발림성도 좋지만 지속력은 별로예요
# 29     각질부각도 적고 지속력도 괜차늠\n매트하다 촉촉하다 거의 갈리는데 나는 좀 매트함ㅇ...
# ...                                                  ...
# 19908                      핑크색 진짜 좋아요 근데 양 조절을 잘해야 되더라구요
# 19909  안네마리 토너류는 거의 다 써봤고 복합성 피부인데도 콤비네이션은 좀 아쉬웠어요. 리...
# 19910  지성/복합성 여름 쿠션으로 짱 추천!\n코에 기름폭발하는 지성인데 그래도 그나마 보...
# 19911  안네마리 제품이 다 유리병이라 벽선반 추락하면서 몇개 깨먹었는데.. 이것도 깨지기 ...
# 19912  복합성 피부인데 여름에 다 귀찮을 때 퍼밍젤이랑 리제너레이션 블로썸듀젤만 바르기 좋...
# 19913  가루날림이 좀있고 지속력도 뛰어난편은 아니지만 색 조합이 매우이쁘다는점에서 계속 손...
# 19914              향은 상큼한 게 기분 좋지만\n에센스가 흡수가 잘 안 되는 거 같음
# 19915                           쓰기 편하고 뚜껑에 거울달려 있어서 좋네요~
# 19916                                          갠적으로진짜도아요
# 19917  아기 귀저기 발진에 좋다고 해서 구매했는데 잘 낫지않아요 비판텐이 직빵이더라구요 오...
# 19918  피부상태가 괜찮을때 요 제품 하나바르면 물광피부처럼~ 아주 깨끗한 피부 표현가능해요...
# 19919  백화점 디올 매장에서 구입했습니다.\n일단 정말 무늬가 조각품 같아요ㅠ 너무 예쁜....
# 19920  성분이 착해서 그런지 피부에 트러블이 안나서 진짜 좋았아요. 용량도 많아서 피부랑 ...
# 19921  무슨 알갱이가 들어가 있는데 타올에 거품 내다보면 흔적도 없이 사라져요. 제 값주고...
# 19922                            진짜 짱 평생 쓸제품\n개털이 머리털됩니다
# 19923                               발색이 넘 잘되서 언제 다 쓸까 싶다
# 19924              애기로션 중에 젤 오래쓰고 많이 썼던 로션. 냄새 너무 좋음~~~♡
# 19925  에이디파잉 트러블라인 스킨케어제품중에 젤 좋았어요! 일단 다른 여드름용화장품에비해서...
# 19926  이거 냄새 좋고 깔끔하고 산뜻하게 발리고 트러블 피부에 효과 좋은데 널리 알려진게 ...
# 19927              냄새도별로고 폼클렌징인데 잘안지워짐\n그냥 아침세안할때 하면 좋아료
# 19928        쓰면서 피부결이 좋아진 것 같다\n특별히 뾰루지가 올라온 적도 없고 나름 만족
# 19929                          세트로 샀었는데 그냥저냥 무난하게 썼던 템..
# 19930            매트하고 끈적끈적하고\n흡수력도 없었어요 별로였습네다\n호갱님이였움..
# 19931  애기 기저귀 갈아줄때 엉덩이에 톡톡 발라주고 있어요\n보송하게 마무리 해서 엉덩이 ...
# 19932  향은 너무 좋아요. 근데 성분이 도대체 뭔지 피부에 묻으면 겁나 따갑고 공기중에 뿌...
# 19933  허니라고 해서 막 무겁고 끈적이지는 않아요! 딱 기분좋은 보습력? 적당한 무게감? ...
# 19934          지성한테는 그냥 그런듯. 미끈거리고 잘 흡수된다는 느낌까지는 받지 못했어여
# 19935                                     한겨울엔 리치한게 딱이지!
# 19936  이것도 엘리X베스 코팩처럼 자극이 심한데 그 제품보다 덜 뽑혀요... 별로에요. 2...
# 19937  이건 세안용으로는쓰면안되고 아침일어나서나 기름기올라온 저녁이나 맨피부상태일때 쓰는,...
#
# [19938 rows x 3 columns]

# %%
df["review"][0]
# Out:
# '트리플어피치 쓰는데 음... 발색도 별로 텍스쳐가 정말 뭐라하지 너무 기름진데 촉촉하진 않다. 색상도 주황색으로 나오는데 쿨톤인 나에겐 정말 겉도는 색이고 틴트 위에 올리면 아무리 붉은틴트를 발랐어도 주황색으로 바꿔줘서 립밤으로도 활용불가....제돈주고 샀으면 땅을 치고 후회했을듯'

# %%
len(df)
# Out:
# 19938

# %%
df.to_csv("cosmetics_reviews.csv", encoding="utf-8", index=False)
